# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks

# %%
df = pd.DataFrame(pd.read_csv("insurance.csv"))
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Checking Null values
df.isnull().sum()
# There are no NULL values in the dataset, hence it is clean.
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df = df.dropna()

# %%
# EDA

# %%
auto=df[['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses']]

# %%
auto
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
# Dimension reduction

# %%
gender = pd.get_dummies(auto['sex'], drop_first = True)
gender
# Out:
#       male
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 1333     1
# 1334     0
# 1335     0
# 1336     0
# 1337     0
#
# [1338 rows x 1 columns]

# %%
auto = pd.concat([auto, gender], axis = 1)
auto
# Out:
#       age     sex   bmi  children smoker     region  expenses  male
# 0      19  female  27.9         0    yes  southwest  16884.92     0
# 1      18    male  33.8         1     no  southeast   1725.55     1
# 2      28    male  33.0         3     no  southeast   4449.46     1
# 3      33    male  22.7         0     no  northwest  21984.47     1
# 4      32    male  28.9         0     no  northwest   3866.86     1
# ...   ...     ...   ...       ...    ...        ...       ...   ...
# 1333   50    male  31.0         3     no  northwest  10600.55     1
# 1334   18  female  31.9         0     no  northeast   2205.98     0
# 1335   18  female  36.9         0     no  southeast   1629.83     0
# 1336   21  female  25.8         0     no  southwest   2007.95     0
# 1337   61  female  29.1         0    yes  northwest  29141.36     0
#
# [1338 rows x 8 columns]

# %%
region_typ = pd.get_dummies(auto['region'], drop_first = True)
region_typ
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
auto = pd.concat([auto, region_typ], axis = 1)
auto
# Out:
#       age     sex   bmi  children smoker     region  expenses  male  \
# 0      19  female  27.9         0    yes  southwest  16884.92     0
# 1      18    male  33.8         1     no  southeast   1725.55     1
# 2      28    male  33.0         3     no  southeast   4449.46     1
# 3      33    male  22.7         0     no  northwest  21984.47     1
# 4      32    male  28.9         0     no  northwest   3866.86     1
# ...   ...     ...   ...       ...    ...        ...       ...   ...
# 1333   50    male  31.0         3     no  northwest  10600.55     1
# 1334   18  female  31.9         0     no  northeast   2205.98     0
# 1335   18  female  36.9         0     no  southeast   1629.83     0
# 1336   21  female  25.8         0     no  southwest   2007.95     0
# 1337   61  female  29.1         0    yes  northwest  29141.36     0
#
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 11 columns]

# %%
smoker = pd.get_dummies(auto['smoker'], drop_first = True)
smoker

# first ma yes xa vane yes ko matra column banxa "drop_first= True" garda natra yes no dubai column banxa False garda
# duita matra category xa vane drop_first= True
# natra false garne
# Out:
#       yes
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
# ...   ...
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
#
# [1338 rows x 1 columns]

# %%
auto = pd.concat([auto, smoker], axis = 1)

# %%
auto
# Out:
#       age     sex   bmi  children smoker     region  expenses  male  \
# 0      19  female  27.9         0    yes  southwest  16884.92     0
# 1      18    male  33.8         1     no  southeast   1725.55     1
# 2      28    male  33.0         3     no  southeast   4449.46     1
# 3      33    male  22.7         0     no  northwest  21984.47     1
# 4      32    male  28.9         0     no  northwest   3866.86     1
# ...   ...     ...   ...       ...    ...        ...       ...   ...
# 1333   50    male  31.0         3     no  northwest  10600.55     1
# 1334   18  female  31.9         0     no  northeast   2205.98     0
# 1335   18  female  36.9         0     no  southeast   1629.83     0
# 1336   21  female  25.8         0     no  southwest   2007.95     0
# 1337   61  female  29.1         0    yes  northwest  29141.36     0
#
#       northwest  southeast  southwest  yes
# 0             0          0          1    1
# 1             0          1          0    0
# 2             0          1          0    0
# 3             1          0          0    0
# 4             1          0          0    0
# ...         ...        ...        ...  ...
# 1333          1          0          0    0
# 1334          0          0          0    0
# 1335          0          1          0    0
# 1336          0          0          1    0
# 1337          1          0          0    1
#
# [1338 rows x 12 columns]

# %%
auto.drop(['sex','region','smoker'], axis = 1, inplace = True)

# %%
auto
# Out:
#       age   bmi  children  expenses  male  northwest  southeast  southwest  \
# 0      19  27.9         0  16884.92     0          0          0          1
# 1      18  33.8         1   1725.55     1          0          1          0
# 2      28  33.0         3   4449.46     1          0          1          0
# 3      33  22.7         0  21984.47     1          1          0          0
# 4      32  28.9         0   3866.86     1          1          0          0
# ...   ...   ...       ...       ...   ...        ...        ...        ...
# 1333   50  31.0         3  10600.55     1          1          0          0
# 1334   18  31.9         0   2205.98     0          0          0          0
# 1335   18  36.9         0   1629.83     0          0          1          0
# 1336   21  25.8         0   2007.95     0          0          0          1
# 1337   61  29.1         0  29141.36     0          1          0          0
#
#       yes
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
# ...   ...
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
#
# [1338 rows x 9 columns]

# %%
# Starting machine learning
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(auto.corr(),annot=True)
plt.show()

# %%
auto = auto[['age',	'bmi',	'children', 'male'	,'southwest'	,'yes','expenses']]

# %%
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
df_train, df_test = train_test_split(auto, train_size = 0.7, test_size = 0.3, random_state = 1)

# %%
df_train
# Out:
#       age   bmi  children  male  southwest  yes  expenses
# 744    50  26.4         0     1          0    0   8827.21
# 363    21  26.4         1     0          1    0   2597.78
# 10     25  26.2         0     1          0    0   2721.32
# 970    50  28.2         3     0          0    0  10702.64
# 634    51  39.7         1     1          1    0   9391.35
# ...   ...   ...       ...   ...        ...  ...       ...
# 715    60  28.9         0     1          1    0  12146.97
# 905    26  29.4         2     0          0    0   4564.19
# 1096   51  35.0         2     0          0    1  44641.20
# 235    40  22.2         2     0          0    1  19444.27
# 1061   57  27.9         1     1          0    0  11554.22
#
# [936 rows x 7 columns]

# %%
df_test
# Out:
#       age   bmi  children  male  southwest  yes  expenses
# 559    19  35.5         0     1          0    0   1646.43
# 1087   57  31.5         0     1          0    0  11353.23
# 1020   51  37.0         0     1          1    0   8798.59
# 460    49  36.6         3     0          0    0  10381.48
# 802    21  22.3         1     1          1    0   2103.08
# ...   ...   ...       ...   ...        ...  ...       ...
# 323    57  40.9         0     1          0    0  11566.30
# 1268   20  33.3         0     0          1    0   1880.49
# 134    20  28.8         0     0          0    0   2457.21
# 1274   26  27.1         0     1          0    1  17043.34
# 876    49  27.1         1     0          1    0  26140.36
#
# [402 rows x 7 columns]

# %%
from sklearn.linear_model import LinearRegression
X_train = df_train[['age',	'bmi',	'children', 'male'	,'southwest'	,'yes']]
y_train = df_train['expenses']
# df_test_predict = X_train.iloc[0:1]
lm = LinearRegression()
model = lm.fit(X_train, y_train)

# model.predict(df_test_predict)

# %%
# Testing
data = df_test.iloc[10:11]
actual_expenses = data.pop('expenses')

print(data)
predicted_expenses = model.predict(data)
print("Actual expenses",actual_expenses)
print("predicted expenses",predicted_expenses)

# print(df_test.iloc[0:1])
# Out:
#     age   bmi  children  male  southwest  yes
# 48   60  24.5         0     0          0    0
# Actual expenses 48    12629.9
# Name: expenses, dtype: float64
# predicted expenses [11629.51068773]

# %%
# Alternet

# %%
# from sklearn.preprocessing import MinMaxScaler

# %%
# scaler = MinMaxScaler()
# scaler

# %%
df_train.head()
# Out:
#      age   bmi  children  male  southwest  yes  expenses
# 744   50  26.4         0     1          0    0   8827.21
# 363   21  26.4         1     0          1    0   2597.78
# 10    25  26.2         0     1          0    0   2721.32
# 970   50  28.2         3     0          0    0  10702.64
# 634   51  39.7         1     1          1    0   9391.35

# %%
df_train.describe()
# Out:
#               age         bmi    children        male   southwest         yes  \
# count  936.000000  936.000000  936.000000  936.000000  936.000000  936.000000
# mean    38.822650   30.684829    1.104701    0.511752    0.256410    0.206197
# std     14.029097    6.087874    1.222664    0.500129    0.436884    0.404790
# min     18.000000   16.000000    0.000000    0.000000    0.000000    0.000000
# 25%     26.000000   26.275000    0.000000    0.000000    0.000000    0.000000
# 50%     38.000000   30.500000    1.000000    1.000000    0.000000    0.000000
# 75%     51.000000   34.725000    2.000000    1.000000    1.000000    0.000000
# max     64.000000   53.100000    5.000000    1.000000    1.000000    1.000000
#
#            expenses
# count    936.000000
# mean   13276.698622
# std    12197.308146
# min     1121.870000
# 25%     4710.600000
# 50%     9188.005000
# 75%    16604.305000
# max    63770.430000

# %%
# Apply scaler() to all the columns except the 'dummy' variables
# num_vars = ['age', 'bmi', 'children', 'expenses']

# df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#      age   bmi  children  male  southwest  yes  expenses
# 744   50  26.4         0     1          0    0   8827.21
# 363   21  26.4         1     0          1    0   2597.78
# 10    25  26.2         0     1          0    0   2721.32
# 970   50  28.2         3     0          0    0  10702.64
# 634   51  39.7         1     1          1    0   9391.35

# %%
df_train.describe()
# Out:
#               age         bmi    children        male   southwest         yes  \
# count  936.000000  936.000000  936.000000  936.000000  936.000000  936.000000
# mean    38.822650   30.684829    1.104701    0.511752    0.256410    0.206197
# std     14.029097    6.087874    1.222664    0.500129    0.436884    0.404790
# min     18.000000   16.000000    0.000000    0.000000    0.000000    0.000000
# 25%     26.000000   26.275000    0.000000    0.000000    0.000000    0.000000
# 50%     38.000000   30.500000    1.000000    1.000000    0.000000    0.000000
# 75%     51.000000   34.725000    2.000000    1.000000    1.000000    0.000000
# max     64.000000   53.100000    5.000000    1.000000    1.000000    1.000000
#
#            expenses
# count    936.000000
# mean   13276.698622
# std    12197.308146
# min     1121.870000
# 25%     4710.600000
# 50%     9188.005000
# 75%    16604.305000
# max    63770.430000

# %%
df_train.corr()
# Out:
#                 age       bmi  children      male  southwest       yes  \
# age        1.000000  0.120120  0.016859  0.004261   0.015629 -0.009185
# bmi        0.120120  1.000000 -0.006109  0.046005   0.002630  0.010558
# children   0.016859 -0.006109  1.000000  0.015476   0.037786 -0.006931
# male       0.004261  0.046005  0.015476  1.000000  -0.004016  0.064620
# southwest  0.015629  0.002630  0.037786 -0.004016   1.000000 -0.021090
# yes       -0.009185  0.010558 -0.006931  0.064620  -0.021090  1.000000
# expenses   0.301822  0.195820  0.032779  0.049507  -0.026116  0.796133
#
#            expenses
# age        0.301822
# bmi        0.195820
# children   0.032779
# male       0.049507
# southwest -0.026116
# yes        0.796133
# expenses   1.000000

# %%
# Let's check the correlation coefficients to see which variables are highly correlated

plt.figure(figsize = (16, 10))
sns.heatmap(df_train.corr(), annot = True,)
plt.show()

# %%
y_train = df_train.pop('expenses')
X_train = df_train

# %%
X_train
# Out:
#       age   bmi  children  male  southwest  yes
# 744    50  26.4         0     1          0    0
# 363    21  26.4         1     0          1    0
# 10     25  26.2         0     1          0    0
# 970    50  28.2         3     0          0    0
# 634    51  39.7         1     1          1    0
# ...   ...   ...       ...   ...        ...  ...
# 715    60  28.9         0     1          1    0
# 905    26  29.4         2     0          0    0
# 1096   51  35.0         2     0          0    1
# 235    40  22.2         2     0          0    1
# 1061   57  27.9         1     1          0    0
#
# [936 rows x 6 columns]

# %%
X_train
# Out:
#       age   bmi  children  male  southwest  yes
# 744    50  26.4         0     1          0    0
# 363    21  26.4         1     0          1    0
# 10     25  26.2         0     1          0    0
# 970    50  28.2         3     0          0    0
# 634    51  39.7         1     1          1    0
# ...   ...   ...       ...   ...        ...  ...
# 715    60  28.9         0     1          1    0
# 905    26  29.4         2     0          0    0
# 1096   51  35.0         2     0          0    1
# 235    40  22.2         2     0          0    1
# 1061   57  27.9         1     1          0    0
#
# [936 rows x 6 columns]

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 10
lm = LinearRegression()
# lm.fit(X_train, y_train)

#rfe = RFE(lm, 10)
rfe = RFE(lm, n_features_to_select=6)
#running RFE
rfe = rfe.fit(X_train, y_train)

# %%
X_train.columns
# Out:
# Index(['age', 'bmi', 'children', 'male', 'southwest', 'yes'], dtype='object')

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('age', True, 1),
#  ('bmi', True, 1),
#  ('children', True, 1),
#  ('male', True, 1),
#  ('southwest', True, 1),
#  ('yes', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['age', 'bmi', 'children', 'male', 'southwest', 'yes'], dtype='object')

# %%
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]
X_train_rfe
# Out:
#       age   bmi  children  male  southwest  yes
# 744    50  26.4         0     1          0    0
# 363    21  26.4         1     0          1    0
# 10     25  26.2         0     1          0    0
# 970    50  28.2         3     0          0    0
# 634    51  39.7         1     1          1    0
# ...   ...   ...       ...   ...        ...  ...
# 715    60  28.9         0     1          1    0
# 905    26  29.4         2     0          0    0
# 1096   51  35.0         2     0          0    1
# 235    40  22.2         2     0          0    1
# 1061   57  27.9         1     1          0    0
#
# [936 rows x 6 columns]

# %%
X_train_rfe
# Out:
#       age   bmi  children  male  southwest  yes
# 744    50  26.4         0     1          0    0
# 363    21  26.4         1     0          1    0
# 10     25  26.2         0     1          0    0
# 970    50  28.2         3     0          0    0
# 634    51  39.7         1     1          1    0
# ...   ...   ...       ...   ...        ...  ...
# 715    60  28.9         0     1          1    0
# 905    26  29.4         2     0          0    0
# 1096   51  35.0         2     0          0    1
# 235    40  22.2         2     0          0    1
# 1061   57  27.9         1     1          0    0
#
# [936 rows x 6 columns]

# %%
# Adding a constant variable
import statsmodels.api as sm
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
X_train_rfe
# Out:
#       const  age   bmi  children  male  southwest  yes
# 744     1.0   50  26.4         0     1          0    0
# 363     1.0   21  26.4         1     0          1    0
# 10      1.0   25  26.2         0     1          0    0
# 970     1.0   50  28.2         3     0          0    0
# 634     1.0   51  39.7         1     1          1    0
# ...     ...  ...   ...       ...   ...        ...  ...
# 715     1.0   60  28.9         0     1          1    0
# 905     1.0   26  29.4         2     0          0    0
# 1096    1.0   51  35.0         2     0          0    1
# 235     1.0   40  22.2         2     0          0    1
# 1061    1.0   57  27.9         1     1          0    0
#
# [936 rows x 7 columns]

# %%
y_train
# Out:
# 744      8827.21
# 363      2597.78
# 10       2721.32
# 970     10702.64
# 634      9391.35
#           ...
# 715     12146.97
# 905      4564.19
# 1096    44641.20
# 235     19444.27
# 1061    11554.22
# Name: expenses, Length: 936, dtype: float64

# %% [markdown]
# Ordinary Least Squares regression (OLS) is a common technique for estimating coefficients of linear regression equations which describe the relationship between one or more independent quantitative variables and a dependent variable (simple or multiple linear regression).

# %%
lm = sm.OLS(y_train,X_train_rfe).fit()  # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               expenses   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     474.2
# Date:                Thu, 07 Sep 2023   Prob (F-statistic):          1.01e-278
# Time:                        11:58:14   Log-Likelihood:                -9478.4
# No. Observations:                 936   AIC:                         1.897e+04
# Df Residuals:                     929   BIC:                         1.900e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.104e+04   1140.863     -9.681      0.000   -1.33e+04   -8805.868
# age          252.5153     14.260     17.708      0.000     224.530     280.501
# bmi          307.0788     32.888      9.337      0.000     242.535     371.622
# children     350.2311    162.554      2.155      0.031      31.215     669.247
# male        -266.8577    398.284     -0.670      0.503   -1048.497     514.782
# southwest   -435.6258    454.932     -0.958      0.339   -1328.438     457.187
# yes         2.404e+04    491.674     48.894      0.000    2.31e+04     2.5e+04
# ==============================================================================
# Omnibus:                      203.523   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              473.321
# Skew:                           1.169   Prob(JB):                    1.66e-103
# Kurtosis:                       5.583   Cond. No.                         294.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Dropping male as p-value is high.
X_train_new1 = X_train_rfe.drop(["southwest"], axis = 1)

X_train_new1
# Out:
#       const  age   bmi  children  male  yes
# 744     1.0   50  26.4         0     1    0
# 363     1.0   21  26.4         1     0    0
# 10      1.0   25  26.2         0     1    0
# 970     1.0   50  28.2         3     0    0
# 634     1.0   51  39.7         1     1    0
# ...     ...  ...   ...       ...   ...  ...
# 715     1.0   60  28.9         0     1    0
# 905     1.0   26  29.4         2     0    0
# 1096    1.0   51  35.0         2     0    1
# 235     1.0   40  22.2         2     0    1
# 1061    1.0   57  27.9         1     1    0
#
# [936 rows x 6 columns]

# %%
# # Adding a constant variable
# import statsmodels.api as sm
# X_train_lm = sm.add_constant(X_train_new1)
# X_train_lm

# %%
lm = sm.OLS(y_train,X_train_new1).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               expenses   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     568.9
# Date:                Thu, 07 Sep 2023   Prob (F-statistic):          6.37e-280
# Time:                        11:58:14   Log-Likelihood:                -9478.8
# No. Observations:                 936   AIC:                         1.897e+04
# Df Residuals:                     930   BIC:                         1.900e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.114e+04   1136.139     -9.808      0.000   -1.34e+04   -8913.922
# age          252.3166     14.258     17.697      0.000     224.335     280.298
# bmi          307.0327     32.887      9.336      0.000     242.492     371.573
# children     344.4004    162.433      2.120      0.034      25.623     663.178
# male        -265.5631    398.263     -0.667      0.505   -1047.162     516.036
# yes         2.405e+04    491.549     48.926      0.000    2.31e+04     2.5e+04
# ==============================================================================
# Omnibus:                      204.913   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              477.842
# Skew:                           1.175   Prob(JB):                    1.73e-104
# Kurtosis:                       5.594   Cond. No.                         293.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_new1 = X_train_rfe.drop(["male"], axis = 1)
lm = sm.OLS(y_train,X_train_new1).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               expenses   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     569.3
# Date:                Thu, 07 Sep 2023   Prob (F-statistic):          5.04e-280
# Time:                        11:58:14   Log-Likelihood:                -9478.6
# No. Observations:                 936   AIC:                         1.897e+04
# Df Residuals:                     930   BIC:                         1.900e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.115e+04   1130.689     -9.857      0.000   -1.34e+04   -8926.014
# age          252.5233     14.256     17.714      0.000     224.546     280.501
# bmi          306.0805     32.845      9.319      0.000     241.622     370.539
# children     348.4474    162.484      2.144      0.032      29.569     667.326
# southwest   -434.5911    454.794     -0.956      0.340   -1327.133     457.951
# yes         2.402e+04    490.513     48.966      0.000    2.31e+04     2.5e+04
# ==============================================================================
# Omnibus:                      204.520   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              477.663
# Skew:                           1.172   Prob(JB):                    1.89e-104
# Kurtosis:                       5.598   Cond. No.                         291.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Dropping northwest as p value is high.
X_train_new2 = X_train_new1.drop(["southwest"], axis = 1)


# # Adding a constant variable
# import statsmodels.api as sm
# X_train_lm = sm.add_constant(X_train_new2)

lm = sm.OLS(y_train,X_train_new2).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               expenses   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     711.4
# Date:                Thu, 07 Sep 2023   Prob (F-statistic):          2.80e-281
# Time:                        11:58:26   Log-Likelihood:                -9479.1
# No. Observations:                 936   AIC:                         1.897e+04
# Df Residuals:                     931   BIC:                         1.899e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.124e+04   1125.970     -9.985      0.000   -1.35e+04   -9033.340
# age          252.3250     14.254     17.702      0.000     224.352     280.298
# bmi          306.0394     32.843      9.318      0.000     241.584     370.494
# children     342.6391    162.363      2.110      0.035      23.999     661.279
# yes         2.403e+04    490.385     48.999      0.000    2.31e+04     2.5e+04
# ==============================================================================
# Omnibus:                      205.887   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              482.143
# Skew:                           1.179   Prob(JB):                    2.01e-105
# Kurtosis:                       5.609   Cond. No.                         290.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_new3 = X_train_new2.drop(["children"], axis = 1)


# # Adding a constant variable
# import statsmodels.api as sm
# X_train_lm = sm.add_constant(X_train_new2)

lm = sm.OLS(y_train,X_train_new3).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               expenses   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     943.6
# Date:                Thu, 07 Sep 2023   Prob (F-statistic):          7.72e-282
# Time:                        11:58:28   Log-Likelihood:                -9481.3
# No. Observations:                 936   AIC:                         1.897e+04
# Df Residuals:                     932   BIC:                         1.899e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.087e+04   1113.797     -9.756      0.000   -1.31e+04   -8680.645
# age          252.8559     14.278     17.710      0.000     224.836     280.876
# bmi          305.4769     32.903      9.284      0.000     240.905     370.049
# yes         2.402e+04    491.282     48.895      0.000    2.31e+04     2.5e+04
# ==============================================================================
# Omnibus:                      204.145   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              471.652
# Skew:                           1.175   Prob(JB):                    3.82e-103
# Kurtosis:                       5.563   Cond. No.                         286.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#expenses  = age*252.8505 + bmi*306.4162 - male*-251.8311 + yes*2.404e+04 - -1.077e+04
