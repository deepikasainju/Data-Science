# %% [markdown]
# <font size=5 color="blue"><b><center> Business Statistics:  Insurance data plot</center></b></font><br>

# %% [markdown]
# **Objective – Explore the dataset and extract insights from the data. Using statistical evidence to**
# - Prove (or disprove) that the medical claims made by the people who smoke is greater than those who don't?
# - Prove (or disprove) with statistical evidence that the BMI of females is different from that of males.
# - Is the proportion of smokers significantly different across different regions?
# - Is the mean BMI of women with no children, one child, and two children the same?<br>
#
# <br>

# %% [markdown]
# # Context
# Leveraging customer information is of paramount importance for most businesses. In the case of an insurance company, attributes of customers like the ones mentioned below can be crucial in making business decisions.

# %% [markdown]
# # Data Set
# - Age :- This is an integer indicating the age of the primary beneficiary (excluding those above 64 years, since they are generally covered by the government).
# - Sex :- This is the policy holder's gender, either male or female.
# - BMI :- This is the body mass index (BMI), which provides a sense of how over or under-weight a person is relative to their height. BMI is equal to weight (in kilograms) divided by height (in meters) squared. An ideal BMI is within the range of 18.5 to 24.9.
# - Children :- This is an integer indicating the number of children / dependents covered by the insurance plan.
# - Smoker :- This is yes or no depending on whether the insured regularly smokes tobacco.
# - Region :- This is the beneficiary's place of residence in the U.S., divided into four geographic regions - northeast, southeast, southwest, or northwest.
# - Charges​ :- Individual medical costs billed to health insurance

# %% [markdown]
# # Question to be answered
# - Are there more Male beneficary ?
# - Are there more smoker ?
# - Which region has maximum , medical cost billed to health insurance.?
# - What is age of beneficary.?
# - Do beneficary having more dependents had more medical cost billed.?
# -

# %% [markdown]
# # Libraries

# %%
### IMPORT: ------------------------------------
import scipy.stats as stats #It has all the probability distributions available along with many statistical functions.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore') # To supress warnings
sns.set(style="darkgrid") # set the background for the graphs
from scipy.stats import skew

# from statsmodels.stats.proportion import proportions_ztest # For proportion Z-test
# from statsmodels.formula.api import ols      # For n-way ANOVA
# from statsmodels.stats.anova import anova_lm # For n-way ANOVA
# from   scipy.stats import chi2_contingency   # For Chi-Sq

# %% [markdown]
# # Read and Understand Data

# %%
#Reading the csv file AxisInsurance.csv
df = pd.read_csv('insurance.csv')
insured=df.copy()

# %%
# inspect data, print top 5
insured.head(5)
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# bottom 5 rows:
insured.tail(5)
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
insured.info()    #it give information about datatype of different columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insured.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
insured.shape
#get the size of dataframe
print ("Rows     : " , insured.shape[0])
print ("Columns  : " , insured.shape[1])
# Out:
# Rows     :  1338
# Columns  :  7

# %%
insured.isnull().sum().values.sum()
# Out:
# 0

# %%
print ("\nValues : \n", insured.values)
print ("\nFeatures : \n", list(insured.columns))
# print ("\nFeatures : \n", list(insured.columns.to_list()))

# print ("\nMissing values :  ", insured.isnull().sum().values.sum())

# print ("\nUnique values :  \n", insured.nunique())
# Out:
# Values :
#  [[19 'female' 27.9 ... 'yes' 'southwest' 16884.92]
#  [18 'male' 33.8 ... 'no' 'southeast' 1725.55]
#  [28 'male' 33.0 ... 'no' 'southeast' 4449.46]
#  ...
#  [18 'female' 36.9 ... 'no' 'southeast' 1629.83]
#  [21 'female' 25.8 ... 'no' 'southwest' 2007.95]
#  [61 'female' 29.1 ... 'yes' 'northwest' 29141.36]]
#
# Features :
#  ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses']

# %%
insured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# **Types of variables**
#
# - Categorical varibles - sex,smoker,region,children
# -  Quantitative variables -age,bmi,charges. Here children is a discrete variable where as age, bmi, and charges are continous variables.
#
# - There are no missing values

# %%
#changing object dtype to category  to save memory
# object dtype takes more memory
insured.sex=insured['sex'].astype("category")
insured.smoker=insured['smoker'].astype("category")
insured.region=insured['region'].astype("category")

# %%
insured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   category
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   category
#  5   region    1338 non-null   category
#  6   expenses  1338 non-null   float64
# dtypes: category(3), float64(2), int64(2)
# memory usage: 46.3 KB

# %%
insured.describe()
# describe ley numerical values lai matra describe garxa
# 50% = median
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %% [markdown]
# **Observations**
#  - Average age of the primary beneficiary is 39.2 and maximum age is 64.
#  - Average BMI is 30.66, that is out of normal BMI range, Maximum BMI is 53.13
#  - Average medical costs billed to health insurance is 13270, median is 9382 and maximum is 63770
#  - Median is less than mean in charges , indicating distrubution is postively skewed .
#  - Customer on an average has 1 child.
#  - For Age, BMI, children , mean is almost equal to median , suggesting data is normally distrubuted

# %%
#Are there more Male beneficary ?
# Are there more smoker ?
# which region has maximum , claims .?

insured.describe(include='category')
# top= top ma vayeko value
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
list_col=  insured.select_dtypes(['category']).columns
# .columns column matra print garna lai category data type ko
print(list_col)
list_col1=insured.select_dtypes(['category'])
# kun data type lo data print garne
list_col1
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1338 rows x 3 columns]

# %%
# single column ko sabai data dinxa
# sex, smoker, region are the columns
for i in list_col:
    print(insured[i])
# Out:
# 0       female
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 1333      male
# 1334    female
# 1335    female
# 1336    female
# 1337    female
# Name: sex, Length: 1338, dtype: category
# Categories (2, object): ['female', 'male']
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: category
# Categories (2, object): ['no', 'yes']
# 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1338, dtype: category
# Categories (4, object): ['northeast', 'northwest', 'southeast', 'southwest']

# %%
# sabai data ko count
for i in insured.columns:
    print(insured[i].value_counts())
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
# male      676
# female    662
# Name: sex, dtype: int64
# 27.6    17
# 33.3    17
# 28.9    16
# 32.3    15
# 29.8    14
#         ..
# 39.0     1
# 40.8     1
# 20.3     1
# 18.5     1
# 53.1     1
# Name: bmi, Length: 275, dtype: int64
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
# no     1064
# yes     274
# Name: smoker, dtype: int64
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64
# 1639.56     2
# 16884.92    1
# 29330.98    1
# 2221.56     1
# 19798.05    1
#            ..
# 7345.08     1
# 26109.33    1
# 28287.90    1
# 1149.40     1
# 29141.36    1
# Name: expenses, Length: 1337, dtype: int64

# %%
# get counts of unique observations for each category variable
list_col=  insured.select_dtypes(['category']).columns
for i in range(len(list_col)):
    print(insured[list_col[i]].value_counts())
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
# no     1064
# yes     274
# Name: smoker, dtype: int64
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# **Observations**
#  - 676 male and 662 female, indicated sample has  slightly more males than females.
#  - 1064 nonsomker and 274 smoker, indicating sample has more nonsmokers.
#  - Number of  claims from customer who reside in southwest region is more compared to other regions

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Univariate Analysis

# %%
# def dist_box(data):
#  # function plots a combined graph for univariate analysis of continous variable
#  #to check spread, central tendency , dispersion and outliers
#     Name=data.name.upper()
#     fig,(ax_box,ax_dis)  = plt.subplots(2,1,gridspec_kw = {"height_ratios": (.25, .75)},figsize=(8, 5))
#     print(fig,(ax_box,ax_dis))
#     mean=data.mean()
#     median=data.median()
#     mode=data.mode().tolist()[0]

#     fig.suptitle(f"SPREAD OF DATA FOR "+ Name  , fontsize=18, fontweight='bold')
#     sns.boxplot(x=data,showmeans=True, orient='h',color="violet",ax=ax_box)
#     ax_box.set(xlabel='')
#     sns.distplot(data,kde=False,color='blue',ax=ax_dis)

#     ax_dis.axvline(mean, color='r', linestyle='--',linewidth=2)
#     ax_dis.axvline(median, color='g', linestyle='-',linewidth=2)
#     ax_dis.axvline(mode, color='y', linestyle='-',linewidth=2)
#     plt.legend({'Mean':mean,'Median':median,'Mode':mode})

# %%
# #select all quantitative columns for checking the spread
# list_col=  insured.select_dtypes([np.number]).columns
# for i in range(len(list_col)):
#     dist_box(insured[list_col[i]])

#     print(insured[list_col[i]])

# %% [markdown]
# **Observations**
# - Age of primary beneficary lies approximately between 20 - 65 . Average Age is aprrox. 40. Majority of customer are in range 18- 20's.
# - Bmi is normally distrubuted and Average BMI of beneficiary is 30.This BMI is outside the normal range of BMI. There are lot of outliers at upper end
# - Most of the beneficary have no childrens.
# - Charges distrubution is unimodal and is right skewed .Average cost incured to the insurance is appro. 13270 and highest charge is 63770.There are lot of outliers at upper end.

# %%
# Function to create barplots that indicate percentage for each category.
def bar_perc(plot, feature):
    total = len(feature) # length of the column
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height()           # hieght of the plot
        plot.annotate(percentage, (x, y), size = 12) # annotate the percentage

# %%
#get all category datatype
list_col=  insured.select_dtypes(['category']).columns
print(list_col)
fig1, axes1 =plt.subplots(1,3,figsize=(14, 5))
for i in range(len(list_col)):
    # order = insured[list_col[i]].value_counts(ascending=False).index # to display bar in ascending order
    order = insured[list_col[i]].value_counts(ascending=False).index # to display bar in ascending order

    axis=sns.countplot(x=list_col[i], data=insured , order=order,ax=axes1[i],palette='viridis').set(title=list_col[i].upper())
    bar_perc(axes1[i],insured[list_col[i]])
    print(order)
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')
# CategoricalIndex(['male', 'female'], categories=['female', 'male'], ordered=False, dtype='category')
# CategoricalIndex(['no', 'yes'], categories=['no', 'yes'], ordered=False, dtype='category')
# CategoricalIndex(['southeast', 'northwest', 'southwest', 'northeast'], categories=['northeast', 'northwest', 'southeast', 'southwest'], ordered=False, dtype='category')

# %%
# Basic alternate visulatization

# %%
len(insured[insured['sex'] == 'male'])
# Out:
# 676

# %%
len(insured[insured['sex'] == 'female'])
# Out:
# 662

# %%
no_of_male = len(insured[insured['sex'] == 'male'])
no_of_female = len(insured[insured['sex'] == 'female'])
plt.bar(['male','female'],[no_of_male,no_of_female],color = ['r','g'],label = ['male','female'])
plt.legend()
plt.plot()
# Out:
# []

# %%
#Alternet
#for gender
no_of_male = len(insured[insured['sex'] == 'male'])
no_of_female = len(insured[insured['sex'] == 'female'])
print(no_of_male,no_of_female)

plt.bar(['Male','Female'],[no_of_male,no_of_female], label='gender')
plt.title('No of male and female')
plt.legend()
plt.show()
# Out:
# 676 662

# %%
southeast = len(insured[insured['region'] == 'southeast'])
northwest = len(insured[insured['region'] == 'northwest'])
southwest = len(insured[insured['region'] == 'southwest'])
northeast = len(insured[insured['region'] == 'northeast'])


plt.bar(['southeast','northwest','southwest','northeast'],
 [southeast,northwest,southwest,northeast], label=['southeast','northwest','southwest','northeast'],
        color = ['b','r','m','c'])
plt.title('Region')
plt.legend()
plt.show()

# %%
# get counts of unique observations for each category variable
list_col=  insured.select_dtypes(['category']).columns
for i in range(len(list_col)):
    print(insured[list_col[i]].value_counts().index)
# index k k ho dinxa

for i in range(len(list_col)):
    print(list(insured[list_col[i]].value_counts()))
#count value dinxa
# Out:
# CategoricalIndex(['male', 'female'], categories=['female', 'male'], ordered=False, dtype='category')
# CategoricalIndex(['no', 'yes'], categories=['no', 'yes'], ordered=False, dtype='category')
# CategoricalIndex(['southeast', 'northwest', 'southwest', 'northeast'], categories=['northeast', 'northwest', 'southeast', 'southwest'], ordered=False, dtype='category')
# [676, 662]
# [1064, 274]
# [364, 325, 325, 324]

# %%
for i in range(len(list_col)):
    print(insured[list_col[i]].value_counts().index, insured[list_col[i]].value_counts())
# index, value dubai dinxa
# Out:
# CategoricalIndex(['male', 'female'], categories=['female', 'male'], ordered=False, dtype='category') male      676
# female    662
# Name: sex, dtype: int64
# CategoricalIndex(['no', 'yes'], categories=['no', 'yes'], ordered=False, dtype='category') no     1064
# yes     274
# Name: smoker, dtype: int64
# CategoricalIndex(['southeast', 'northwest', 'southwest', 'northeast'], categories=['northeast', 'northwest', 'southeast', 'southwest'], ordered=False, dtype='category') southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %%
for i in range(len(list_col)):
    print(list(insured[list_col[i]].value_counts().index), list(insured[list_col[i]].value_counts()))
# index, value dubai dinxa list ko form ma
# Out:
# ['male', 'female'] [676, 662]
# ['no', 'yes'] [1064, 274]
# ['southeast', 'northwest', 'southwest', 'northeast'] [364, 325, 325, 324]

# %%
data = {}
list_col=  insured.select_dtypes(['category']).columns
for i in range(len(list_col)):
  values = list(insured[list_col[i]].value_counts()) # category ko data values count nikaleko
  subcategory = list(insured[list_col[i]].value_counts().index) # index haru
  # data['x'] = values
  data[list_col[i]] = [subcategory,values] # dict ma list add gardai gayeko

data
# Out:
# {'sex': [['male', 'female'], [676, 662]],
#  'smoker': [['no', 'yes'], [1064, 274]],
#  'region': [['southeast', 'northwest', 'southwest', 'northeast'],
#   [364, 325, 325, 324]]}

# %%
data = {}
list_col=  insured.select_dtypes(['category']).columns
for i in list_col:
  # print(i,list(insured[i].value_counts().index),list(insured[i].value_counts()))
  data[i] = [list(insured[i].value_counts().index),list(insured[i].value_counts())]

data
# Out:
# {'sex': [['male', 'female'], [676, 662]],
#  'smoker': [['no', 'yes'], [1064, 274]],
#  'region': [['southeast', 'northwest', 'southwest', 'northeast'],
#   [364, 325, 325, 324]]}

# %%
# Bar Graph

# %%
print(data['region'][0])
print(data['region'][1])
# Out:
# ['southeast', 'northwest', 'southwest', 'northeast']
# [364, 325, 325, 324]

# %%
#Alternate
print(data['region'])
plt.bar(data['region'][0],data['region'][1],
        label=['southeast', 'northwest', 'southwest', 'northeast'],
        color = ['r','b','g','k'])
plt.title('Region')
plt.legend()
plt.show()
# Out:
# [['southeast', 'northwest', 'southwest', 'northeast'], [364, 325, 325, 324]]

# %%
#Alternate
print(data['smoker'])
plt.bar(data['smoker'][0],data['smoker'][1],
        label=['no','yes'],
        color = ['g','r'])
plt.title('Smokers')
plt.legend()
plt.show()
# Out:
# [['no', 'yes'], [1064, 274]]

# %%
#Alternate
print(data['sex'])
plt.bar(data['sex'][0],data['sex'][1],
        label=['male','female'],
        color = ['b','r'])
plt.title('Sex')
plt.legend()
plt.show()
# Out:
# [['male', 'female'], [676, 662]]

# %%
# univariate analysis vaneko counting garne

# %% [markdown]
# **Observations**
#  - 50.5% of beneficiary are male and 49.5 % are female. Approximately same number of male and female beneficiary.
#  - 20.5% of beneficary are smokers.
#  - Beneficary are evenly distributed across regions with South East being the most populous one (~27%) with the rest of regions each containing around ~24%
#  - Most of the beneficiary don't have kid.

# %% [markdown]
# ## Bivariate & Multivariate Analysis

# %%
insured
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
# correlation= relation betn two or more variables 
insured.corr()
# age increase hunda children increase hune chance is 0.04=4% .
# categorical values ko correlation nikalna mildaina
# Out:
#                age       bmi  children  expenses
# age       1.000000  0.109341  0.042469  0.299008
# bmi       0.109341  1.000000  0.012645  0.198576
# children  0.042469  0.012645  1.000000  0.067998
# expenses  0.299008  0.198576  0.067998  1.000000

# %%
# mathi ko lai boxz type ma print gareko
plt.figure(figsize=(15,5))
sns.heatmap(insured.corr(),annot=True)
# values pani print garna lai annot true garxa
# value badhai janda color dark hunxa
plt.show()

# %% [markdown]
# **Observation**
#  - There is  very little significant correlation between charges &age and charges and bmi.

# %%
cat_columns=insured.select_dtypes(['category']).columns
cat_columns
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
# imported from seaborn
# correlation lai plot gareko for visualization
plt.figure(figsize=(5,5))
sns.pairplot(data=insured , corner=True)
plt.show()
# euta age ra expense linda euta point aauxa

# %% [markdown]
# **Observation**
#  - Avergae Age of female beneficiary is slightly higher than male beneficiary
#  - No of children both male and female beneficary have is same
#  - BMI of Male policy holder has many outliers and Average BMI of male is slightly higher than female
#  - Male policy holder has incure more charges to insurance compared to female policy holder. There are lot of outliers in female policy holder

# %% [markdown]
# **Observation**
# - Smoker have incured more cost to insurance than nonsmoker. There are outliers in nonsmoker , need to analyze.
# - BMI of non smoker has lot of outliers.

# %% [markdown]
# **Observations**
#  - Age  and numnber of children across regions is almost same.
#  - Average Bmi of policy holder from southeast higher compared to other regions
#  - Charges incured because of policy holder from southeast is higher compared to othe regions
#  - There are lot of outliers on upper end in charges

# %%
# Function to create barplots that indicate percentage for each category.
def bar_perc(plot, feature):
    total = len(feature) # length of the column
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height()           # hieght of the plot
        plot.annotate(percentage, (x, y), size = 12) # annotate the percentage

# %%
#smoker vs Sex
plt.figure(figsize=(13,5))
ax=sns.countplot(x='smoker',hue='sex',data=insured)
# hue= sex garda , smoker non-smoker ma pani kati jana male ra female ma divide garne
bar_perc(ax,insured['sex'])

# %%
#sex vs Smoker
plt.figure(figsize=(13,5))
ax=sns.countplot(x='sex',hue='smoker',data=insured)
# smoker non-smoker ma pani male ra female ma divide garne
bar_perc(ax,insured['smoker'])

# %%
#smoker vs charges
# categorical data xaina vane barplot garne
sns.barplot(x=insured.smoker,y=insured.expenses).set(title="Smoker vs Charges")
# Out:
# [Text(0.5, 1.0, 'Smoker vs Charges')]

# %%
#region vs smoker
plt.figure(figsize=(10,5))
ax=sns.countplot(x='region',hue='smoker',data=insured)
bar_perc(ax,insured['smoker'])
ax.set(title="Region vs Smoker")
# Out:
# [Text(0.5, 1.0, 'Region vs Smoker')]

# %%
#Smoker vs Region
plt.figure(figsize=(10,5))
ax=sns.countplot(x='smoker',hue='region',data=insured)
bar_perc(ax,insured['region'])
ax.set(title="Smoker vs Region")
# Out:
# [Text(0.5, 1.0, 'Smoker vs Region')]

# %% [markdown]
# **Observation**
# - There are more male smokers than female.
# - Southeast region has more smokers
# - Smoker have more costlier claims than nonsmoker.

# %%
plt.figure(figsize=(13,5))
ax=sns.countplot(x='region',hue='sex',data=insured,palette='spring')
bar_perc(ax,insured['sex'])
ax.set(title="Sex vs Region")
# Out:
# [Text(0.5, 1.0, 'Sex vs Region')]

# %% [markdown]
# **Observations**
#  - There are more smokers in southeast region compared to other regions.

# %%
insured.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# GROUP BY

# %%
insured.groupby(insured.sex).expenses.mean()      #GROUP BY BY SEX
# average expenses of male ra female
# sabai male ko expense jodxa ani tesko mean nikalxa
# Out:
# sex
# female    12569.578897
# male      13956.751420
# Name: expenses, dtype: float64

# %%
insured.groupby(insured.region).expenses.mean()      #GROUP BY BY region
# harek region ko xutai sum garera mean nikalne
# Out:
# region
# northeast    13406.384691
# northwest    12417.575169
# southeast    14735.411538
# southwest    12346.937908
# Name: expenses, dtype: float64

# %%
insured.groupby(insured.smoker).expenses.mean()      #GROUP BY BY smoker
# group ma xutayexi expenses ko mean nikalne
# Out:
# smoker
# no      8434.268449
# yes    32050.231971
# Name: expenses, dtype: float64

# %%
insured.groupby(insured.children).expenses.mean()      #GROUP BY BY children
# Out:
# children
# 0    12365.975767
# 1    12731.171821
# 2    15073.564000
# 3    15355.318535
# 4    13850.656800
# 5     8786.035556
# Name: expenses, dtype: float64

# %% [markdown]
# countplot vs barplot
# countplot vaneko values count garna lai use hunxa for example kati jana male female
# countplot ma univariate analysis pani garna milxa
# barplot ma x y dubai define garna parxa

# %%
ax = sns.barplot(x=insured.children,y=insured.expenses).set(title="Children vs Charges")
# x axis ma children yaxis ma expenses
# bar_perc(ax,insured['sex'])
# ax.set(title="Sex vs Region")

# %%
sns.barplot(x=insured.sex,y=insured.expenses).set(title='Sex Vs Charges')
# Out:
# [Text(0.5, 1.0, 'Sex Vs Charges')]

# %%
sns.barplot(x='region',y='expenses',data=insured).set(title='Region Vs Charges')
# euta region ma average expenses kati xa plot gareko
# barplot ma x-axis=categorial values y-axis= numerical values
# Out:
# [Text(0.5, 1.0, 'Region Vs Charges')]

# %%
#multivariate
# three dimensional analysis
plt.figure(figsize=(15,7))
sns.lineplot(x = insured["age"], y =insured["expenses"],hue=insured["sex"],ci=0).set(title= 'Cost incured by Age for Female and Males')
# yeti age female ra male ko average expenses
# ci=0 ley area hatauxa 
plt.legend(bbox_to_anchor=(0.5, 1)) #0.5= x-axis ko bich ma and 1=y-axis ko top ma halne 
# legend ko position
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x = insured["age"], y =insured["expenses"],hue=insured["sex"]).set(title= 'Cost incured by Age for Female and Males')
plt.legend()
plt.show()
# area pani plot vayeko

# %%
#Cross tab
df_smoker_char_sex1=pd.crosstab(index=insured.smoker, columns=insured.sex  , values=insured.expenses, aggfunc='mean')
df_smoker_char_sex1
# index ma smoker haleko
# non smoker ma female ko average expenses and so on
# Out:
# sex           female          male
# smoker
# no       8762.297367   8087.204971
# yes     30678.996261  33042.006226

# %%
df_smoker_char_sex=pd.crosstab(index=insured.sex, columns=  insured.smoker, values=insured.expenses,aggfunc='sum')
df_smoker_char_sex
# index ma sex haleko
# female haru ma non-smoker ko expenses ko sum
# Out:
# smoker          no         yes
# sex
# female  4792976.66  3528084.57
# male    4181084.97  5253678.99

# %% [markdown]
# # plot directly from data frame

# %%
# direct data frame bata plot gareko
df_smoker_char_sex1.plot(kind='bar',title="Smoker Vs Charges for Males and Females")
# smoke garne ra nagarne ko avg expenses of male and female
plt.legend(loc='upper left')
plt.show()

# %%
df_smoker_char_sex=pd.crosstab(index=insured.region, columns=  insured.sex, values=insured.expenses,aggfunc='mean')
df_smoker_char_sex
# Out:
# sex              female          male
# region
# northeast  12953.203106  13854.005767
# northwest  12479.870244  12354.119317
# southeast  13499.669257  15879.617354
# southwest  11274.411667  13412.884233

# %%
df_smoker_char_sex.plot(kind='bar',title="Region Vs Charges for Males and Females")
plt.legend(loc='upper left')
plt.show()
# harek region ko avg expenses of female and male

# %% [markdown]
# **Observations**
#  - Charges incurred for males are more than charges incured for females
#  - With increasing age of policy holder charges incured are going high for both male and female.
#  - There some spikes for female at an approximate ages of 23,28,43.
#  - Most claims are from southeast regions.
#  - Males who smoke have most claims and have higher bills
#  - Number of claims made by female who dont smoke is more compared to female who smoke.

# %%
# converting quantitative data to qualitative
insured
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
#creating groups of bmi
# kati dekhi kati sama bmi vayeka ko data
category = pd.cut(insured.bmi,bins=[15,25,35,45,55],labels=['15-25','25-35','35-45','45-55'])
# bins 15 dekhi 55 sama vayeko lai 10 range ma differentiate garne
# 15 sata 15-25, 25 ko satta 25-35
insured.insert(5,'BMIGroup',category)
# insured ko 5th column ma category=BMIGroup haldine

# %%
insured.head()
# Out:
#    age     sex   bmi  children smoker BMIGroup     region  expenses
# 0   19  female  27.9         0    yes    25-35  southwest  16884.92
# 1   18    male  33.8         1     no    25-35  southeast   1725.55
# 2   28    male  33.0         3     no    25-35  southeast   4449.46
# 3   33    male  22.7         0     no    15-25  northwest  21984.47
# 4   32    male  28.9         0     no    25-35  northwest   3866.86

# %%
insured.groupby(insured.BMIGroup).expenses.mean()
# BMIGroup lai group garera tesko average expenses nikalne
# Out:
# BMIGroup
# 15-25    10284.290121
# 25-35    12720.254413
# 35-45    16913.681791
# 45-55    17547.927500
# Name: expenses, dtype: float64

# %%
category1=pd.cut(insured.age,bins=[16,28,38,48,58,68],labels=['16-28','28-38','38-48','48-58','58-68'])
insured.insert(6,'AgeBin',category1)

# %%
insured.head()
# Out:
#    age     sex   bmi  children smoker BMIGroup AgeBin     region  expenses
# 0   19  female  27.9         0    yes    25-35  16-28  southwest  16884.92
# 1   18    male  33.8         1     no    25-35  16-28  southeast   1725.55
# 2   28    male  33.0         3     no    25-35  16-28  southeast   4449.46
# 3   33    male  22.7         0     no    15-25  28-38  northwest  21984.47
# 4   32    male  28.9         0     no    25-35  28-38  northwest   3866.86

# %%
age_bin_cat = insured.groupby(insured.AgeBin).expenses.mean()
age_bin_cat
# Out:
# AgeBin
# 16-28     9096.110000
# 28-38    11598.555097
# 38-48    14334.586014
# 48-58    15887.954489
# 58-68    20824.973022
# Name: expenses, dtype: float64

# %%
age_bin_cat.plot(kind='bar',title="Age Range Vs Average Charges")
# 16-28 age ko average expenses
# Out:
# <Axes: title={'center': 'Age Range Vs Average Charges'}, xlabel='AgeBin'>

# %%
#multi variate data analysis
insured.groupby(['region','sex','smoker']).expenses.mean()
# tinta columns lai group garera expenses ko mean nikaleko
# Out:
# region     sex     smoker
# northeast  female  no         9640.427121
#                    yes       28032.045517
#            male    no         8664.042640
#                    yes       30926.252895
# northwest  female  no         8786.998519
#                    yes       29670.824828
#            male    no         8320.689167
#                    yes       30713.180690
# southeast  female  no         8440.205396
#                    yes       33034.821389
#            male    no         7609.003731
#                    yes       36029.839636
# southwest  female  no         8234.091702
#                    yes       31687.988571
#            male    no         7778.906111
#                    yes       32598.863784
# Name: expenses, dtype: float64

# %%
insured.groupby(['region','sex','smoker']).expenses.mean().unstack()
# unstack garda data frame ma represent hunxa
# Out:
# smoker                     no           yes
# region    sex
# northeast female  9640.427121  28032.045517
#           male    8664.042640  30926.252895
# northwest female  8786.998519  29670.824828
#           male    8320.689167  30713.180690
# southeast female  8440.205396  33034.821389
#           male    7609.003731  36029.839636
# southwest female  8234.091702  31687.988571
#           male    7778.906111  32598.863784

# %%
plt.figure(figsize=(15,7))
sns.barplot(x=insured["BMIGroup"],y=insured["age"],hue=insured['sex'],ci=0).set(title= 'Age and Bmi of Males and Females')
# x axis ma bmigroup, y axis ma age, hue ma sex 
# so 3 dimensional plot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %%
sns.barplot(x='BMIGroup',y='expenses',hue='sex',data=insured).set(title="Fig 2:BMI group and Charges " )
# yesma data frame last ma matra define gareko xa
# Out:
# [Text(0.5, 1.0, 'Fig 2:BMI group and Charges ')]

# %% [markdown]
# **Observations**
# - FeMales with most BMI has incured most charges to the insurance company
# - BMI for male and females are not same
# - Beneficary with higher BMI have incurred more cost to insurance.

# %%
pd.crosstab(insured['sex'],insured['children'])
# female ko kati jana children xa
# male ko kati jana children xa
# bivariate analysis
# Out:
# children    0    1    2   3   4   5
# sex
# female    289  158  119  77  11   8
# male      285  166  121  80  14  10

# %%
sns.relplot(x=insured.BMIGroup, y=insured.expenses, hue=insured.smoker, size= insured.AgeBin,
            sizes=(40, 400), palette="spring",
            height=6, data=insured).set(title='Charges by Age,BMI,Smoker');
# relplot= bubble plot
# x axis ma independent varaiable
# y axis ma dependent variable
# agebin ko anusar bubble ko size thulo sano hunxa
# big bubble age small
# small bubble age big
# height= graph ko size lai define garxa

# %%
insured
# Out:
#       age     sex   bmi  children smoker BMIGroup AgeBin     region  expenses
# 0      19  female  27.9         0    yes    25-35  16-28  southwest  16884.92
# 1      18    male  33.8         1     no    25-35  16-28  southeast   1725.55
# 2      28    male  33.0         3     no    25-35  16-28  southeast   4449.46
# 3      33    male  22.7         0     no    15-25  28-38  northwest  21984.47
# 4      32    male  28.9         0     no    25-35  28-38  northwest   3866.86
# ...   ...     ...   ...       ...    ...      ...    ...        ...       ...
# 1333   50    male  31.0         3     no    25-35  48-58  northwest  10600.55
# 1334   18  female  31.9         0     no    25-35  16-28  northeast   2205.98
# 1335   18  female  36.9         0     no    35-45  16-28  southeast   1629.83
# 1336   21  female  25.8         0     no    25-35  16-28  southwest   2007.95
# 1337   61  female  29.1         0    yes    25-35  58-68  northwest  29141.36
#
# [1338 rows x 9 columns]

# %%
sns.relplot(x=insured.AgeBin, y=insured.expenses, hue=insured.sex, size= insured.BMIGroup,
            sizes=(40, 400), palette="spring",
            height=5, data=insured).set(title='Charges by Age,BMI,Smoker');

# %% [markdown]
# **Observation**
# - Males who smoker have incured more cost compared to nonsmokers.
# - As age increased claims increased
# - Smoker have higher medical claims

# %% [markdown]
# # download tableau

# %% [markdown]
# # Conclusion based on EDA
# - As expected , as the age of the beneficiary  increases ,the cost to insurance increases.
# - Males who smoke have most claims and have higher bills.
# - Female who are nonsmoker also have more claims to nonsmoker males this may be because of child birth , need to explore claims type to understand better.
# - Beneficiary with 2 or 3 dependent  have billed higher compared to others people who have 5.This is unusual and may be because of  uneven number of observations in each group. For example, no dependents group has 574 observations whereas five dependents group only has 18.
# - Customer with bmi  >30 are  on higher side of obesity, have more health issues and have higher claims.
# - Females with BMI more than 45 have billed higher to insurance.
# - Age, BMI and Smoking are important attributes which can cost insurance company more.

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# # 1.Prove (or disprove) that the medical claims made by the people who smoke is greater than those who don't?

# %% [markdown]
# <div class ="alert alert-block alert-info">
#
# ---
#
#
#     <font size=3><b>    Step 1: Define null and alternative hypothesis</b></font><br>
# $\ H_0  :  \mu_1 <= \mu_2  $ The average charges of smokers is less than or equal to nonsmokers
#  <br>
#
#
# $\ H_a  :\mu_1 > \mu_2 $ The average charges of smokers is greater than nonsmokers  <br>
# </div>

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 2: Decide the significance level. If P values is less than alpha reject the null hypothesis.</b></font>
#
# α = 0.05

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 3: Identify the test</b></font>
#
# Standard deviation of the population is not known  ,will perform a T stat test .  The > sign in alternate hypothesis indicate  test is right tailed, that is all z values that would cause us to reject null hypothesis are in just one tail to the right of  sampling  distribution curve.

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 4: Calculate the test-statistics and p-value</b></font>

# %%
smoker=insured.loc[insured.smoker=="yes"]
smoker.head()
# Out:
#     age     sex   bmi  children smoker BMIGroup AgeBin     region  expenses
# 0    19  female  27.9         0    yes    25-35  16-28  southwest  16884.92
# 11   62  female  26.3         0    yes    25-35  58-68  southeast  27808.73
# 14   27    male  42.1         0    yes    35-45  16-28  southeast  39611.76
# 19   30    male  35.3         0    yes    35-45  28-38  southwest  36837.47
# 23   34  female  31.9         1    yes    25-35  28-38  northeast  37701.88

# %%
smoker.count()
# Out:
# age         274
# sex         274
# bmi         274
# children    274
# smoker      274
# BMIGroup    274
# AgeBin      274
# region      274
# expenses    274
# dtype: int64

# %%
nonsmoker=insured.loc[insured.smoker=='no']
nonsmoker.head()
# Out:
#    age     sex   bmi  children smoker BMIGroup AgeBin     region  expenses
# 1   18    male  33.8         1     no    25-35  16-28  southeast   1725.55
# 2   28    male  33.0         3     no    25-35  16-28  southeast   4449.46
# 3   33    male  22.7         0     no    15-25  28-38  northwest  21984.47
# 4   32    male  28.9         0     no    25-35  28-38  northwest   3866.86
# 5   31  female  25.7         0     no    25-35  28-38  southeast   3756.62

# %%
nonsmoker.count()
# Out:
# age         1064
# sex         1064
# bmi         1064
# children    1064
# smoker      1064
# BMIGroup    1064
# AgeBin      1064
# region      1064
# expenses    1064
# dtype: int64

# %%
# Adjusting the size of the rows to be equal
nonsmoker = nonsmoker[0:274]
charges_yes = smoker.expenses
charges_no = nonsmoker.expenses

# %%
print(f'Average Cost charged to Insurance for smoker is {charges_yes.mean()} and nonsmoker is {charges_no.mean()} ')
# Out:
# Average Cost charged to Insurance for smoker is 32050.23197080292 and nonsmoker is 8460.786167883212

# %%
#smoker vs charges
sns.boxplot(x=insured.expenses,y=insured.smoker,data=insured).set(title="Fig:1 Smoker vs Charges")
# Out:
# [Text(0.5, 1.0, 'Fig:1 Smoker vs Charges')]

# %%
charges_no
# Out:
# 1       1725.55
# 2       4449.46
# 3      21984.47
# 4       3866.86
# 5       3756.62
#          ...
# 350    11830.61
# 351     8932.08
# 352     3554.20
# 353    12404.88
# 354    14133.04
# Name: expenses, Length: 274, dtype: float64

# %%
alpha = 0.05
t_statistic_1, p_value_1 = stats.ttest_ind(charges_yes, charges_no)
p_value_onetail=p_value_1/2

print("Test statistic = {} , Pvalue ={} , OnetailPvalue = {}".format(t_statistic_1,p_value_1, p_value_onetail ))
# Out:
# Test statistic = 29.96693762930951 , Pvalue =2.11900162618799e-117 , OnetailPvalue = 1.059500813093995e-117

# %%
if p_value_1 < alpha :
    print(f"Conclusion:Since P value {p_value_onetail} is less than alpha {alpha} " )
    # print("Reject Null Hypothesis that Average charges for smokers are less than or equal to nonsmoker.")

else:
    print("Conclusion:Since P value {} is greater than alpha {} ". format (p_value_onetail,alpha))
    # print("Failed to Reject Null Hypothesis that Average charges for smokers are less than nonsmoker.")
# Out:
# Conclusion:Since P value 1.059500813093995e-117 is less than alpha 0.05

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 5: Decide whethere to  reject or failed to reject null hypothesis</b></font><br>
#     We reject the null hypothesis and can conclude that people who smoke have on an average larger medical claim compared to people who don't smoke. Similar result can also been seen in Fig no.1 Smokers Vs Charges

# %% [markdown]
# # 2.Prove (or disprove) with statistical evidence that the BMI of females is different from that of males.

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     Let $\mu_1 \mu_2 $ and be the respective population means for BMI of males and BMI of females<br>
#     <font size=3><b>    Step 1: Define null and alternative hypothesis</b></font><br>
# $\ H_0  : \mu_1 - \mu_2 = 0$ There is no difference between the BMI of Male  and BMI of female.<br>
# $\ H_a  : \mu_1 - \mu_2 !=0 $ There is difference between the BMI of Male and BMI of female. <br>
#
#
# </div>

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 2: Decide the significance level</b></font>
#
# α = 0.05

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 3:Identify the test</b></font><br>Standard deviation of the population is not known ,will perform a T stat test.Not equal to sign in alternate hypothesis indicate its a two tailed test.

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 4: Calculate the test-statistics and p-value</b></font>

# %%
#get all observation for male.
df_male=insured.loc[insured.sex=="male"]
#get all observation for females
df_female=insured.loc[insured.sex=="female"]

# %%
#get bmi of male and female
bmi_female=df_female.bmi
bmi_male=df_male.bmi

# %%
sns.distplot(bmi_male,color='green',hist=False)
sns.distplot(bmi_female,color='red',hist=False)
# Out:
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
df_female.bmi.mean()
# Out:
# 30.3797583081571

# %%
df_male.bmi.mean()
# Out:
# 30.94526627218935

# %%
# get statistic and p value
t_statistic_2, p_value_2 = stats.ttest_ind(bmi_male, bmi_female)
print("tstats = ",t_statistic_2, ", pvalue = ", p_value_2)
# Out:
# tstats =  1.6970846764986391 , pvalue =  0.08991356987176295

# %%
if p_value_2 <alpha :
    print("Conclusion:Since P value {} is less than alpha {} ". format (p_value_2,alpha) )
    print("Reject Null Hypothesis  that there is no difference in bmi of men and bmi of female.")

else:
    print("Conclusion:Since P value {} is greater than alpha {} ". format (p_value_2,alpha))
    print("Failed to Reject Null Hypothesis  that there is difference in bmi of men and bmi of female .")
# Out:
# Conclusion:Since P value 0.08991356987176295 is greater than alpha 0.05
# Failed to Reject Null Hypothesis  that there is difference in bmi of men and bmi of female .

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 5: Decide to reject or accept null hypothesis</b></font><br>
#      We fail to reject the null hypothesis and can conclude that There is no difference between BMI of Female and BMI of Male.

# %% [markdown]
# ### Recommendation
# - Based on EDA and statistical  evidence it can be seen that  customer who smoke or   have higher  BMI  have more higher claims. We can encourage customers to quit smoking by providing them  incentive points  for talking to life coach, get help for improving lifestyle habits,  Quit Tobacco- 28 day program. Give gift cards when customer accumulates specific number of points.
# - We can have Active wellness programs which can help up reduce claims related to BMI.
# - High BMI  is primarily because of unhealthy life choices. We can provide customers with Diet plans and wellness health coaches which can help them to make right choices.
# - Provide discount coupons  for Gym  or  fitness devices encouraging customers to exercise.
